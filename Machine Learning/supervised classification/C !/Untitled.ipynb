# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def train_logistic(X, y, lr=0.1, epochs=1000):
    m, n = X.shape
    print(m,n)
    weights = np.zeros(n)  # Initialize weights for features (excluding bias)
    bias = 0.0  # Separate bias term

    for epoch in range(epochs):
        # Linear combination for z (including separate bias term)
        z = np.dot(X, weights) + bias  # We now add the bias separately
        
        # Predicted probabilities using sigmoid
        predictions = sigmoid(z)

        # Calculate gradients for weights and bias
        gradient_weights = (1/m) * np.dot(X.T, (predictions - y))  # Gradient for weights
        gradient_bias = (1/m) * np.sum(predictions - y)  # Gradient for bias

        # Update weights and bias using gradient descent
        weights -= lr * gradient_weights
        bias -= lr * gradient_bias

        # Print variables at specific intervals for monitoring
        loss = -np.mean(y * np.log(predictions + 1e-15) + (1 - y) * np.log(1 - predictions + 1e-15))
            
        print(f"Epoch {epoch}")
        print(f"  Weights: {weights}")
        print(f"  Bias: {bias}")
        print(f"  Z: {z}")
        print(f" actual{y}")
        print(f"  Predictions: {predictions}")
        print(f"{predictions - y}")
        print(f"  Gradient for Weights: {gradient_weights}")
        print(f"  Gradient for Bias: {gradient_bias}")
        print(f"  Loss: {loss:.4f}")
        print("-" * 50) 
            

    return weights, bias  # Return both weights and bias

# Example usage:
X = np.array([[0], [1], [3], [4]])  # Example input
y = np.array([1, 1, 0, 0])  # Example labels

weights, bias = train_logistic(X, y, lr=0.1, epochs=1000)
print("Final Weights:", weights)
print("Final Bias:", bias)
# Out:
# 4 1
# Epoch 0
#   Weights: [-0.075]
#   Bias: 0.0
#   Z: [0. 0. 0. 0.]
#  actual[1 1 0 0]
#   Predictions: [0.5 0.5 0.5 0.5]
# [-0.5 -0.5  0.5  0.5]
#   Gradient for Weights: [0.75]
#   Gradient for Bias: 0.0
#   Loss: 0.6931
# --------------------------------------------------
# Epoch 1
#   Weights: [-0.13788618]
#   Bias: 0.0037299405808703515
#   Z: [ 0.    -0.075 -0.225 -0.3  ]
#  actual[1 1 0 0]
#   Predictions: [0.5        0.48125878 0.44398611 0.42555748]
# [-0.5        -0.51874122  0.44398611  0.42555748]
#   Gradient for Weights: [0.62886176]
#   Gradient for Bias: -0.037299405808703515
#   Loss: 0.6415
# --------------------------------------------------
# Epoch 2
#   Weights: [-0.1911058]
#   Bias: 0.010411329805914218
#   Z: [ 0.00372994 -0.13415624 -0.40992859 -0.54781476]
#  actual[1 1 0 0]
#   Predictions: [0.50093248 0.46651115 0.39892924 0.36637155]
# [-0.49906752 -0.53348885  0.39892924  0.36637155]
#   Gradient for Weights: [0.53219627]
#   Gradient for Bias: -0.06681389225043866
#   Loss: 0.6048
# --------------------------------------------------
# Epoch 3
#   Weights: [-0.23668995]
#   Bias: 0.019401960331158024
#   Z: [ 0.01041133 -0.18069447 -0.56290608 -0.75401188]
#  actual[1 1 0 0]
#   Predictions: [0.50260281 0.45494889 0.36287532 0.31994776]
# [-0.49739719 -0.54505111  0.36287532  0.31994776]
#   Gradient for Weights: [0.45584147]
#   Gradient for Bias: -0.08990630525243806
#   Loss: 0.5780
# --------------------------------------------------
# Epoch 4
#   Weights: [-0.27622466]
#   Bias: 0.030199794353613158
#   Z: [ 0.01940196 -0.21728799 -0.69066789 -0.92735784]
#  actual[1 1 0 0]
#   Predictions: [0.50485034 0.44589073 0.33388451 0.28346106]
# [-0.49514966 -0.55410927  0.33388451  0.28346106]
#   Gradient for Weights: [0.39534713]
#   Gradient for Bias: -0.10797834022455133
#   Loss: 0.5577
# --------------------------------------------------
# Epoch 5
#   Weights: [-0.31092217]
#   Bias: 0.04241944318298355
#   Z: [ 0.03019979 -0.24602487 -0.79847419 -1.07469886]
#  actual[1 1 0 0]
#   Predictions: [0.50754937 0.43880216 0.310352   0.25451052]
# [-0.49245063 -0.56119784  0.310352    0.25451052]
#   Gradient for Weights: [0.34697506]
#   Gradient for Bias: -0.12219648829370396
#   Loss: 0.5418
# --------------------------------------------------
# Epoch 6
#   Weights: [-0.34170685]
#   Bias: 0.05576530075965508
#   Z: [ 0.04241944 -0.26850273 -0.89034706 -1.20126923]
#  actual[1 1 0 0]
#   Predictions: [0.51060327 0.43327471 0.29103821 0.2312495 ]
# [-0.48939673 -0.56672529  0.29103821  0.2312495 ]
#   Gradient for Weights: [0.30784684]
#   Gradient for Bias: -0.13345857576671522
#   Loss: 0.5289
# --------------------------------------------------
# Epoch 7
#   Weights: [-0.36928839]
#   Bias: 0.0700089596168297
#   Z: [ 0.0557653  -0.28594155 -0.96935526 -1.31106211]
#  actual[1 1 0 0]
#   Predictions: [0.51393771 0.42899773 0.27500903 0.21230917]
# [-0.48606229 -0.57100227  0.27500903  0.21230917]
#   Gradient for Weights: [0.27581538]
#   Gradient for Bias: -0.1424365885717461
#   Loss: 0.5181
# --------------------------------------------------
# Epoch 8
#   Weights: [-0.3942175]
#   Bias: 0.08497202445944013
#   Z: [ 0.07000896 -0.29927943 -1.03785621 -1.4071446 ]
#  actual[1 1 0 0]
#   Predictions: [0.51749509 0.42573364 0.26156385 0.19668482]
# [-0.48250491 -0.57426636  0.26156385  0.19668482]
#   Gradient for Weights: [0.24929112]
#   Gradient for Bias: -0.14963064842610435
#   Loss: 0.5087
# --------------------------------------------------
# Epoch 9
#   Weights: [-0.41692678]
#   Bias: 0.10051350121786132
#   Z: [ 0.08497202 -0.30924548 -1.09768048 -1.49189798]
#  actual[1 1 0 0]
#   Predictions: [0.52123023 0.42329892 0.25017475 0.18363702]
# [-0.47876977 -0.57670108  0.25017475  0.18363702]
#   Gradient for Weights: [0.22709282]
#   Gradient for Bias: -0.15541476758421188
#   Loss: 0.5005
# --------------------------------------------------
# Epoch 10
#   Weights: [-0.43776025]
#   Bias: 0.1165206381725897
#   Z: [ 0.1005135  -0.31641328 -1.15026685 -1.56719363]
#  actual[1 1 0 0]
#   Predictions: [0.52510724 0.42155011 0.24044035 0.17261683]
# [-0.47489276 -0.57844989  0.24044035  0.17261683]
#   Gradient for Weights: [0.20833462]
#   Gradient for Bias: -0.1600713695472839
#   Loss: 0.4931
# --------------------------------------------------
# Epoch 11
#   Weights: [-0.4569947]
#   Bias: 0.13290226166176644
#   Z: [ 0.11652064 -0.32123961 -1.1967601  -1.63452034]
#  actual[1 1 0 0]
#   Predictions: [0.52909725 0.42037368 0.23205208 0.16321206]
# [-0.47090275 -0.57962632  0.23205208  0.16321206]
#   Gradient for Weights: [0.19234454]
#   Gradient for Bias: -0.16381623489176741
#   Loss: 0.4864
# --------------------------------------------------
# Epoch 12
#   Weights: [-0.47485536]
#   Bias: 0.14958388916148002
#   Z: [ 0.13290226 -0.32409244 -1.23808184 -1.69507653]
#  actual[1 1 0 0]
#   Predictions: [0.53317675 0.41967871 0.22477005 0.15510939]
# [-0.46682325 -0.58032129  0.22477005  0.15510939]
#   Gradient for Weights: [0.17860661]
#   Gradient for Bias: -0.16681627499713586
#   Loss: 0.4801
# --------------------------------------------------
# Epoch 13
#   Weights: [-0.49152734]
#   Bias: 0.16650410779921185
#   Z: [ 0.14958389 -0.32527147 -1.27498219 -1.74983755]
#  actual[1 1 0 0]
#   Predictions: [0.5373264  0.41939159 0.21840558 0.14806769]
# [-0.4626736  -0.58060841  0.21840558  0.14806769]
#   Gradient for Weights: [0.16671977]
#   Gradient for Bias: -0.16920218637731838
#   Loss: 0.4742
# --------------------------------------------------
# Epoch 14
#   Weights: [-0.5071642]
#   Bias: 0.18361185911996722
#   Z: [ 0.16650411 -0.32502323 -1.3080779  -1.79960524]
#  actual[1 1 0 0]
#   Predictions: [0.54153012 0.41945204 0.21280866 0.14189913]
# [-0.45846988 -0.58054796  0.21280866  0.14189913]
#   Gradient for Weights: [0.15636863]
#   Gradient for Bias: -0.1710775132075537
#   Loss: 0.4686
# --------------------------------------------------
# Epoch 15
#   Weights: [-0.52189444]
#   Bias: 0.20086437884276637
#   Z: [ 0.18361186 -0.32355234 -1.33788074 -1.84504494]
#  actual[1 1 0 0]
#   Predictions: [0.54577444 0.41981026 0.20785879 0.13645573]
# [-0.45422556 -0.58018974  0.20785879  0.13645573]
#   Gradient for Weights: [0.14730238]
#   Gradient for Bias: -0.17252519722799162
#   Loss: 0.4633
# --------------------------------------------------
# Epoch 16
#   Weights: [-0.53582639]
#   Bias: 0.2182256150988403
#   Z: [ 0.20086438 -0.32103006 -1.36481893 -1.88671337]
#  actual[1 1 0 0]
#   Predictions: [0.55004794 0.42042474 0.20345822 0.13161966]
# [-0.44995206 -0.57957526  0.20345822  0.13161966]
#   Gradient for Weights: [0.13931951]
#   Gradient for Bias: -0.17361236256073947
#   Loss: 0.4582
# --------------------------------------------------
# Epoch 17
#   Weights: [-0.54905204]
#   Bias: 0.23566500017599387
#   Z: [ 0.21822562 -0.31760077 -1.38925355 -1.92507994]
#  actual[1 1 0 0]
#   Predictions: [0.55434092 0.42126057 0.19952695 0.12729616]
# [-0.44565908 -0.57873943  0.19952695  0.12729616]
#   Gradient for Weights: [0.13225651]
#   Gradient for Bias: -0.17439385077153574
#   Loss: 0.4533
# --------------------------------------------------
# Epoch 18
#   Weights: [-0.56165]
#   Bias: 0.2531564864167142
#   Z: [ 0.235665   -0.31338704 -1.41149112 -1.96054316]
#  actual[1 1 0 0]
#   Predictions: [0.55864508 0.42228822 0.19599897 0.12340828]
# [-0.44135492 -0.57771178  0.19599897  0.12340828]
#   Gradient for Weights: [0.12597956]
#   Gradient for Bias: -0.17491486240720314
#   Loss: 0.4485
# --------------------------------------------------
# Epoch 19
#   Weights: [-0.57368782]
#   Bias: 0.2706777817087861
#   Z: [ 0.25315649 -0.30849351 -1.4317935  -1.9934435 ]
#  actual[1 1 0 0]
#   Predictions: [0.56295327 0.4234825  0.19281939 0.11989303]
# [-0.43704673 -0.5765175   0.19281939  0.11989303]
#   Gradient for Weights: [0.1203782]
#   Gradient for Bias: -0.1752129529207193
#   Loss: 0.4439
# --------------------------------------------------
# Epoch 20
#   Weights: [-0.58522387]
#   Bias: 0.2882097374128596
#   Z: [ 0.27067778 -0.30301003 -1.45038567 -2.02407348]
#  actual[1 1 0 0]
#   Predictions: [0.56725929 0.42482182 0.18994222 0.11669844]
# [-0.43274071 -0.57517818  0.18994222  0.11669844]
#   Gradient for Weights: [0.11536056]
#   Gradient for Bias: -0.1753195570407351
#   Loss: 0.4394
# --------------------------------------------------
# Epoch 21
#   Weights: [-0.59630884]
#   Bias: 0.3057358539127592
#   Z: [ 0.28820974 -0.29701413 -1.46746188 -2.05268575]
#  actual[1 1 0 0]
#   Predictions: [0.57155779 0.42628756 0.1873287  0.11378128]
# [-0.42844221 -0.57371244  0.1873287   0.11378128]
#   Gradient for Weights: [0.1108497]
#   Gradient for Bias: -0.175261164998996
#   Loss: 0.4351
# --------------------------------------------------
# Epoch 22
#   Weights: [-0.60698692]
#   Bias: 0.32324187781518254
#   Z: [ 0.30573585 -0.29057299 -1.48319067 -2.07949951]
#  actual[1 1 0 0]
#   Predictions: [0.57584409 0.4278636  0.18494597 0.11110539]
# [-0.42415591 -0.5721364   0.18494597  0.11110539]
#   Gradient for Weights: [0.10678076]
#   Gradient for Bias: -0.1750602390242334
#   Loss: 0.4308
# --------------------------------------------------
# Epoch 23
#   Weights: [-0.61729679]
#   Bias: 0.3407154712244315
#   Z: [ 0.32324188 -0.28374504 -1.49771888 -2.1047058 ]
#  actual[1 1 0 0]
#   Predictions: [0.58011412 0.42953587 0.18276599 0.10864028]
# [-0.41988588 -0.57046413  0.18276599  0.10864028]
#   Gradient for Weights: [0.10309874]
#   Gradient for Bias: -0.17473593409248955
#   Loss: 0.4266
# --------------------------------------------------
# Epoch 24
#   Weights: [-0.62727247]
#   Bias: 0.3581459381967569
#   Z: [ 0.34071547 -0.27658132 -1.51117491 -2.1284717 ]
#  actual[1 1 0 0]
#   Predictions: [0.58436431 0.43129211 0.18076474 0.10636017]
# [-0.41563569 -0.56870789  0.18076474  0.10636017]
#   Gradient for Weights: [0.09975675]
#   Gradient for Bias: -0.17430466972325384
#   Loss: 0.4225
# --------------------------------------------------
# Epoch 25
#   Weights: [-0.63694392]
#   Bias: 0.37552399693413957
#   Z: [ 0.35814594 -0.26912653 -1.52367146 -2.15094393]
#  actual[1 1 0 0]
#   Predictions: [0.58859154 0.43312154 0.17892151 0.10424305]
# [-0.41140846 -0.56687846  0.17892151  0.10424305]
#   Gradient for Weights: [0.09671457]
#   Gradient for Bias: -0.17378058737382673
#   Loss: 0.4185
# --------------------------------------------------
# Epoch 26
#   Weights: [-0.64633769]
#   Bias: 0.3928415888533746
#   Z: [ 0.375524   -0.26141993 -1.53530778 -2.1722517 ]
#  actual[1 1 0 0]
#   Predictions: [0.59279309 0.43501469 0.17721842 0.10227012]
# [-0.40720691 -0.56498531  0.17721842  0.10227012]
#   Gradient for Weights: [0.09393761]
#   Gradient for Bias: -0.17317591919235062
#   Loss: 0.4146
# --------------------------------------------------
# Epoch 27
#   Weights: [-0.65547728]
#   Bias: 0.4100917176045529
#   Z: [ 0.39284159 -0.2534961  -1.54617147 -2.19250915]
#  actual[1 1 0 0]
#   Predictions: [0.59696657 0.43696318 0.17563992 0.10042519]
# [-0.40303343 -0.56303682  0.17563992  0.10042519]
#   Gradient for Weights: [0.09139592]
#   Gradient for Bias: -0.17250128751178254
#   Loss: 0.4107
# --------------------------------------------------
# Epoch 28
#   Weights: [-0.66438363]
#   Bias: 0.427268312584196
#   Z: [ 0.41009172 -0.24538556 -1.55634011 -2.21181739]
#  actual[1 1 0 0]
#   Predictions: [0.60110987 0.43895959 0.17417244 0.09869429]
# [-0.39889013 -0.56104041  0.17417244  0.09869429]
#   Gradient for Weights: [0.08906352]
#   Gradient for Bias: -0.17176594979643134
#   Loss: 0.4069
# --------------------------------------------------
# Epoch 29
#   Weights: [-0.67307541]
#   Bias: 0.4443661126143298
#   Z: [ 0.42726831 -0.23711532 -1.56588258 -2.23026621]
#  actual[1 1 0 0]
#   Predictions: [0.60522118 0.44099736 0.17280416 0.09706531]
# [-0.39477882 -0.55900264  0.17280416  0.09706531]
#   Gradient for Weights: [0.08691776]
#   Gradient for Bias: -0.1709780003013376
#   Loss: 0.4032
# --------------------------------------------------
# Epoch 30
#   Weights: [-0.68156929]
#   Bias: 0.46138056632754665
#   Z: [ 0.44436611 -0.22870929 -1.5748601  -2.24793551]
#  actual[1 1 0 0]
#   Predictions: [0.60929889 0.44307062 0.17152465 0.09552769]
# [-0.39070111 -0.55692938  0.17152465  0.09552769]
#   Gradient for Weights: [0.08493883]
#   Gradient for Bias: -0.17014453713216834
#   Loss: 0.3995
# --------------------------------------------------
# Epoch 31
#   Weights: [-0.68988022]
#   Bias: 0.4783077464735116
#   Z: [ 0.46138057 -0.22018872 -1.5833273  -2.26489659]
#  actual[1 1 0 0]
#   Predictions: [0.61334163 0.44517415 0.17032477 0.09407224]
# [-0.38665837 -0.55482585  0.17032477  0.09407224]
#   Gradient for Weights: [0.08310935]
#   Gradient for Bias: -0.16927180145964976
#   Loss: 0.3959
# --------------------------------------------------
# Epoch 32
#   Weights: [-0.69802163]
#   Bias: 0.495144275891267
#   Z: [ 0.47830775 -0.21157248 -1.59133293 -2.28121315]
#  actual[1 1 0 0]
#   Predictions: [0.61734819 0.44730331 0.16919645 0.09269088]
# [-0.38265181 -0.55269669  0.16919645  0.09269088]
#   Gradient for Weights: [0.08141404]
#   Gradient for Bias: -0.1683652941775544
#   Loss: 0.3924
# --------------------------------------------------
# Epoch 33
#   Weights: [-0.70600557]
#   Bias: 0.5118872633087481
#   Z: [ 0.49514428 -0.20287735 -1.59892061 -2.29694224]
#  actual[1 1 0 0]
#   Predictions: [0.62131754 0.44945391 0.16813253 0.09137652]
# [-0.37868246 -0.55054609  0.16813253  0.09137652]
#   Gradient for Weights: [0.0798394]
#   Gradient for Bias: -0.16742987417481095
#   Loss: 0.3889
# --------------------------------------------------
# Epoch 34
#   Weights: [-0.71384292]
#   Bias: 0.5285342474619685
#   Z: [ 0.51188726 -0.1941183  -1.60612944 -2.31213501]
#  actual[1 1 0 0]
#   Predictions: [0.62524879 0.45162224 0.16712668 0.09012292]
# [-0.37475121 -0.54837776  0.16712668  0.09012292]
#   Gradient for Weights: [0.07837349]
#   Gradient for Bias: -0.16646984153220362
#   Loss: 0.3855
# --------------------------------------------------
# Epoch 35
#   Weights: [-0.72154349]
#   Bias: 0.545083148290776
#   Z: [ 0.52853425 -0.18530867 -1.6129945  -2.32683742]
#  actual[1 1 0 0]
#   Predictions: [0.62914118 0.45380495 0.16617328 0.08892455]
# [-0.37085882 -0.54619505  0.16617328  0.08892455]
#   Gradient for Weights: [0.07700575]
#   Gradient for Bias: -0.1654890082880743
#   Loss: 0.3821
# --------------------------------------------------
# Epoch 36
#   Weights: [-0.72911617]
#   Bias: 0.5615322241805971
#   Z: [ 0.54508315 -0.17646034 -1.61954733 -2.34109082]
#  actual[1 1 0 0]
#   Predictions: [0.63299409 0.45599903 0.16526731 0.08777653]
# [-0.36700591 -0.54400097  0.16526731  0.08777653]
#   Gradient for Weights: [0.07572677]
#   Gradient for Bias: -0.16449075889821102
#   Loss: 0.3788
# --------------------------------------------------
# Epoch 37
#   Weights: [-0.73656899]
#   Bias: 0.5778800343913724
#   Z: [ 0.56153222 -0.16758395 -1.62581628 -2.35493245]
#  actual[1 1 0 0]
#   Predictions: [0.63680699 0.45820179 0.16440429 0.08667451]
# [-0.36319301 -0.54179821  0.16440429  0.08667451]
#   Gradient for Weights: [0.07452818]
#   Gradient for Bias: -0.16347810210775232
#   Loss: 0.3755
# --------------------------------------------------
# Epoch 38
#   Weights: [-0.74390924]
#   Bias: 0.5941254059545116
#   Z: [ 0.57788003 -0.15868895 -1.63182693 -2.36839592]
#  actual[1 1 0 0]
#   Predictions: [0.64057946 0.46041081 0.16358024 0.08561463]
# [-0.35942054 -0.53958919  0.16358024  0.08561463]
#   Gradient for Weights: [0.07340252]
#   Gradient for Bias: -0.16245371563139246
#   Loss: 0.3723
# --------------------------------------------------
# Epoch 39
#   Weights: [-0.75114355]
#   Bias: 0.6102674044327997
#   Z: [ 0.59412541 -0.14978383 -1.63760231 -2.38151155]
#  actual[1 1 0 0]
#   Predictions: [0.64431114 0.46262389 0.16279158 0.08459344]
# [-0.35568886 -0.53737611  0.16279158  0.08459344]
#   Gradient for Weights: [0.0723431]
#   Gradient for Bias: -0.16141998478288175
#   Loss: 0.3691
# --------------------------------------------------
# Epoch 40
#   Weights: [-0.75827795]
#   Bias: 0.6263053080318972
#   Z: [ 0.6102674  -0.14087614 -1.64316324 -2.39430679]
#  actual[1 1 0 0]
#   Predictions: [0.6480018  0.4648391  0.1620351  0.08360786]
# [-0.3519982  -0.5351609   0.1620351   0.08360786]
#   Gradient for Weights: [0.07134396]
#   Gradient for Bias: -0.16037903599097567
#   Loss: 0.3660
# --------------------------------------------------
# Epoch 41
#   Weights: [-0.76531792]
#   Bias: 0.6422385846294335
#   Z: [ 0.62630531 -0.13197264 -1.64852853 -2.40680647]
#  actual[1 1 0 0]
#   Predictions: [0.65165123 0.46705464 0.16130792 0.08265514]
# [-0.34834877 -0.53294536  0.16130792  0.08265514]
#   Gradient for Weights: [0.07039974]
#   Gradient for Bias: -0.15933276597536242
#   Loss: 0.3629
# --------------------------------------------------
# Epoch 42
#   Weights: [-0.77226848]
#   Bias: 0.6580668713518394
#   Z: [ 0.64223858 -0.12307933 -1.65371517 -2.41903309]
#  actual[1 1 0 0]
#   Predictions: [0.65525932 0.46926895 0.16060747 0.08173279]
# [-0.34474068 -0.53073105  0.16060747  0.08173279]
#   Gradient for Weights: [0.06950563]
#   Gradient for Bias: -0.1582828672240583
#   Loss: 0.3599
# --------------------------------------------------
# Epoch 43
#   Weights: [-0.77913421]
#   Bias: 0.673789956382508
#   Z: [ 0.65806687 -0.11420161 -1.65873858 -2.43100706]
#  actual[1 1 0 0]
#   Predictions: [0.658826   0.47148059 0.1599314  0.08083861]
# [-0.341174   -0.52851941  0.1599314   0.08083861]
#   Gradient for Weights: [0.0686573]
#   Gradient for Bias: -0.1572308503066866
#   Loss: 0.3569
# --------------------------------------------------
# Epoch 44
#   Weights: [-0.7859193]
#   Bias: 0.6894077627295881
#   Z: [ 0.67378996 -0.10534426 -1.66361268 -2.4427469 ]
#  actual[1 1 0 0]
#   Predictions: [0.66235127 0.47368826 0.15927763 0.07997058]
# [-0.33764873 -0.52631174  0.15927763  0.07997058]
#   Gradient for Weights: [0.06785087]
#   Gradient for Bias: -0.15617806347080093
#   Loss: 0.3540
# --------------------------------------------------
# Epoch 45
#   Weights: [-0.79262758]
#   Bias: 0.7049203337192865
#   Z: [ 0.68940776 -0.09651154 -1.66835014 -2.45426944]
#  actual[1 1 0 0]
#   Predictions: [0.66583517 0.47589083 0.15864427 0.07912689]
# [-0.33416483 -0.52410917  0.15864427  0.07912689]
#   Gradient for Weights: [0.0670828]
#   Gradient for Bias: -0.15512570989698418
#   Loss: 0.3511
# --------------------------------------------------
# Epoch 46
#   Weights: [-0.79926258]
#   Bias: 0.7203278200122577
#   Z: [ 0.70492033 -0.08770725 -1.67296241 -2.46558999]
#  actual[1 1 0 0]
#   Predictions: [0.66927777 0.47808723 0.15802961 0.07830593]
# [-0.33072223 -0.52191277  0.15802961  0.07830593]
#   Gradient for Weights: [0.06634995]
#   Gradient for Bias: -0.15407486292971226
#   Loss: 0.3483
# --------------------------------------------------
# Epoch 47
#   Weights: [-0.80582752]
#   Bias: 0.7356304679675035
#   Z: [ 0.72032782 -0.07893476 -1.67745991 -2.47672248]
#  actual[1 1 0 0]
#   Predictions: [0.6726792  0.48027655 0.15743211 0.07750622]
# [-0.3273208  -0.51972345  0.15743211  0.07750622]
#   Gradient for Weights: [0.06564944]
#   Gradient for Bias: -0.15302647955245813
#   Loss: 0.3455
# --------------------------------------------------
# Epoch 48
#   Weights: [-0.81232539]
#   Bias: 0.7508286092010308
#   Z: [ 0.73563047 -0.07019705 -1.68185209 -2.48767961]
#  actual[1 1 0 0]
#   Predictions: [0.67603962 0.48245794 0.15685038 0.07672641]
# [-0.32396038 -0.51754206  0.15685038  0.07672641]
#   Gradient for Weights: [0.06497868]
#   Gradient for Bias: -0.15198141233527224
#   Loss: 0.3427
# --------------------------------------------------
# Epoch 49
#   Weights: [-0.81875892]
#   Bias: 0.7659226512059879
#   Z: [ 0.75082861 -0.06149678 -1.68614755 -2.49847294]
#  actual[1 1 0 0]
#   Predictions: [0.67935922 0.48463065 0.15628315 0.0759653 ]
# [-0.32064078 -0.51536935  0.15628315  0.0759653 ]
#   Gradient for Weights: [0.06433532]
#   Gradient for Bias: -0.15094042004957073
#   Loss: 0.3400
# --------------------------------------------------
# Epoch 50
#   Weights: [-0.82513064]
#   Bias: 0.7809130689176725
#   Z: [ 0.76592265 -0.05283627 -1.69035411 -2.50911303]
#  actual[1 1 0 0]
#   Predictions: [0.68263822 0.48679401 0.15572928 0.07522179]
# [-0.31736178 -0.51320599  0.15572928  0.07522179]
#   Gradient for Weights: [0.06371725]
#   Gradient for Bias: -0.14990417711684606
#   Loss: 0.3373
# --------------------------------------------------
# Epoch 51
#   Weights: [-0.8314429]
#   Bias: 0.7958003971211233
#   Z: [ 0.78091307 -0.04421758 -1.69447886 -2.51960951]
#  actual[1 1 0 0]
#   Predictions: [0.68587687 0.48894741 0.15518773 0.07449486]
# [-0.31412313 -0.51105259  0.15518773  0.07449486]
#   Gradient for Weights: [0.06312252]
#   Gradient for Bias: -0.14887328203450698
#   Loss: 0.3347
# --------------------------------------------------
# Epoch 52
#   Weights: [-0.83769783]
#   Bias: 0.8105852236113485
#   Z: [ 0.7958004  -0.0356425  -1.69852829 -2.52997119]
#  actual[1 1 0 0]
#   Predictions: [0.68907543 0.49109032 0.15465758 0.07378362]
# [-0.31092457 -0.50890968  0.15465758  0.07378362]
#   Gradient for Weights: [0.06254938]
#   Gradient for Bias: -0.1478482649022529
#   Loss: 0.3320
# --------------------------------------------------
# Epoch 53
#   Weights: [-0.84389746]
#   Bias: 0.8252681830269133
#   Z: [ 0.81058522 -0.02711261 -1.70250828 -2.54020611]
#  actual[1 1 0 0]
#   Predictions: [0.6922342  0.49322226 0.15413795 0.07308721]
# [-0.3077658  -0.50677774  0.15413795  0.07308721]
#   Gradient for Weights: [0.06199624]
#   Gradient for Bias: -0.1468295941556476
#   Loss: 0.3295
# --------------------------------------------------
# Epoch 54
#   Weights: [-0.85004362]
#   Bias: 0.8398499512868493
#   Z: [ 0.82526818 -0.01862927 -1.70642419 -2.55032165]
#  actual[1 1 0 0]
#   Predictions: [0.69535348 0.49534282 0.15362809 0.07240488]
# [-0.30464652 -0.50465718  0.15362809  0.07240488]
#   Gradient for Weights: [0.06146165]
#   Gradient for Bias: -0.14581768259935918
#   Loss: 0.3269
# --------------------------------------------------
# Epoch 55
#   Weights: [-0.85613805]
#   Bias: 0.8543312405688941
#   Z: [ 0.83984995 -0.01019367 -1.71028092 -2.56032454]
#  actual[1 1 0 0]
#   Predictions: [0.69843361 0.4974516  0.15312728 0.07173593]
# [-0.30156639 -0.5025484   0.15312728  0.07173593]
#   Gradient for Weights: [0.06094429]
#   Gradient for Bias: -0.14481289282044865
#   Loss: 0.3245
# --------------------------------------------------
# Epoch 56
#   Weights: [-0.86218235]
#   Bias: 0.8687127947740715
#   Z: [ 8.54331241e-01 -1.80681118e-03 -1.71408291e+00 -2.57022097e+00]
#  actual[1 1 0 0]
#   Predictions: [0.70147493 0.4995483  0.15263489 0.07107971]
# [-0.29852507 -0.5004517   0.15263489  0.07107971]
#   Gradient for Weights: [0.06044296]
#   Gradient for Bias: -0.14381554205177377
#   Loss: 0.3220
# --------------------------------------------------
# Epoch 57
#   Weights: [-0.868178]
#   Bias: 0.8829953854287448
#   Z: [ 0.86871279  0.00653045 -1.71783425 -2.58001659]
#  actual[1 1 0 0]
#   Predictions: [0.70447779 0.50163261 0.15215034 0.07043564]
# [-0.29552221 -0.49836739  0.15215034  0.07043564]
#   Gradient for Weights: [0.05995655]
#   Gradient for Bias: -0.14282590654673347
#   Loss: 0.3196
# --------------------------------------------------
# Epoch 58
#   Weights: [-0.87412641]
#   Bias: 0.897179807980644
#   Z: [ 0.88299539  0.01481738 -1.72153862 -2.58971662]
#  actual[1 1 0 0]
#   Predictions: [0.70744255 0.50370428 0.15167309 0.06980318]
# [-0.29255745 -0.49629572  0.15167309  0.06980318]
#   Gradient for Weights: [0.05948406]
#   Gradient for Bias: -0.14184422551899242
#   Loss: 0.3172
# --------------------------------------------------
# Epoch 59
#   Weights: [-0.88002887]
#   Bias: 0.9112668784500719
#   Z: [ 0.89717981  0.0230534  -1.72519942 -2.59932583]
#  actual[1 1 0 0]
#   Predictions: [0.71036961 0.50576309 0.15120266 0.06918182]
# [-0.28963039 -0.49423691  0.15120266  0.06918182]
#   Gradient for Weights: [0.05902459]
#   Gradient for Bias: -0.14087070469427931
#   Loss: 0.3148
# --------------------------------------------------
# Epoch 60
#   Weights: [-0.8858866]
#   Bias: 0.9252574304016424
#   Z: [ 0.91126688  0.03123801 -1.72881972 -2.60884859]
#  actual[1 1 0 0]
#   Predictions: [0.71325934 0.50780887 0.15073861 0.06857111]
# [-0.28674066 -0.49219113  0.15073861  0.06857111]
#   Gradient for Weights: [0.05857728]
#   Gradient for Bias: -0.13990551951570515
#   Loss: 0.3125
# --------------------------------------------------
# Epoch 61
#   Weights: [-0.89170073]
#   Bias: 0.9391523122055574
#   Z: [ 0.92525743  0.03937083 -1.73240236 -2.61828895]
#  actual[1 1 0 0]
#   Predictions: [0.71611213 0.50984144 0.15028055 0.06797061]
# [-0.28388787 -0.49015856  0.15028055  0.06797061]
#   Gradient for Weights: [0.05814138]
#   Gradient for Bias: -0.1389488180391494
#   Loss: 0.3102
# --------------------------------------------------
# Epoch 62
#   Weights: [-0.89747235]
#   Bias: 0.9529523845606587
#   Z: [ 0.93915231  0.04745158 -1.73594989 -2.62765062]
#  actual[1 1 0 0]
#   Predictions: [0.7189284  0.51186067 0.1498281  0.06737994]
# [-0.2810716  -0.48813933  0.1498281   0.06737994]
#   Gradient for Weights: [0.05771618]
#   Gradient for Bias: -0.1380007235510125
#   Loss: 0.3079
# --------------------------------------------------
# Epoch 63
#   Weights: [-0.90320246]
#   Bias: 0.9666585182543513
#   Z: [ 0.95295238  0.05548003 -1.73946467 -2.63693702]
#  actual[1 1 0 0]
#   Predictions: [0.72170854 0.51386645 0.14938094 0.06679872]
# [-0.27829146 -0.48613355  0.14938094  0.06679872]
#   Gradient for Weights: [0.05730104]
#   Gradient for Bias: -0.13706133693692682
#   Loss: 0.3057
# --------------------------------------------------
# Epoch 64
#   Weights: [-0.90889199]
#   Bias: 0.9802715921370304
#   Z: [ 0.96665852  0.06345606 -1.74294885 -2.64615131]
#  actual[1 1 0 0]
#   Predictions: [0.72445297 0.51585869 0.14893876 0.06622662]
# [-0.27554703 -0.48414131  0.14893876  0.06622662]
#   Gradient for Weights: [0.05689536]
#   Gradient for Bias: -0.13613073882679075
#   Loss: 0.3035
# --------------------------------------------------
# Epoch 65
#   Weights: [-0.91454185]
#   Bias: 0.9937924912908963
#   Z: [ 0.98027159  0.0713796  -1.74640438 -2.65529638]
#  actual[1 1 0 0]
#   Predictions: [0.7271621  0.51783733 0.14850128 0.06566332]
# [-0.2728379  -0.48216267  0.14850128  0.06566332]
#   Gradient for Weights: [0.05649861]
#   Gradient for Bias: -0.135208991538659
#   Loss: 0.3013
# --------------------------------------------------
# Epoch 66
#   Weights: [-0.92015288]
#   Bias: 1.007222105375051
#   Z: [ 0.99379249  0.07925064 -1.74983307 -2.66437492]
#  actual[1 1 0 0]
#   Predictions: [0.72983636 0.5198023  0.14806825 0.06510853]
# [-0.27016364 -0.4801977   0.14806825  0.06510853]
#   Gradient for Weights: [0.05611029]
#   Gradient for Bias: -0.1342961408415464
#   Loss: 0.2992
# --------------------------------------------------
# Epoch 67
#   Weights: [-0.92572588]
#   Bias: 1.0205613271305531
#   Z: [ 1.00722211  0.08706922 -1.75323654 -2.67338943]
#  actual[1 1 0 0]
#   Predictions: [0.73247616 0.52175356 0.14763944 0.06456197]
# [-0.26752384 -0.47824644  0.14763944  0.06456197]
#   Gradient for Weights: [0.05572994]
#   Gradient for Bias: -0.13339221755502276
#   Loss: 0.2971
# --------------------------------------------------
# Epoch 68
#   Weights: [-0.93126159]
#   Bias: 1.033811051030709
#   Z: [ 1.02056133  0.09483545 -1.7566163  -2.68234218]
#  actual[1 1 0 0]
#   Predictions: [0.73508192 0.52369111 0.14721463 0.06402338]
# [-0.26491808 -0.47630889  0.14721463  0.06402338]
#   Gradient for Weights: [0.05535713]
#   Gradient for Bias: -0.1324972390015587
#   Loss: 0.2950
# --------------------------------------------------
# Epoch 69
#   Weights: [-0.93676074]
#   Bias: 1.046972172063298
#   Z: [ 1.03381105  0.10254946 -1.75997372 -2.69123531]
#  actual[1 1 0 0]
#   Predictions: [0.73765408 0.52561492 0.14679363 0.06349253]
# [-0.26234592 -0.47438508  0.14679363  0.06349253]
#   Gradient for Weights: [0.05499148]
#   Gradient for Bias: -0.13161121032589143
#   Loss: 0.2930
# --------------------------------------------------
# Epoch 70
#   Weights: [-0.942224]
#   Bias: 1.0600455846327166
#   Z: [ 1.04697217  0.11021143 -1.76331004 -2.70007078]
#  actual[1 1 0 0]
#   Predictions: [0.74019305 0.527525   0.14637627 0.06296918]
# [-0.25980695 -0.472475    0.14637627  0.06296918]
#   Gradient for Weights: [0.05463263]
#   Gradient for Bias: -0.1307341256941842
#   Loss: 0.2909
# --------------------------------------------------
# Epoch 71
#   Weights: [-0.94765203]
#   Bias: 1.0730321815711594
#   Z: [ 1.06004558  0.11782158 -1.76662642 -2.70885042]
#  actual[1 1 0 0]
#   Predictions: [0.74269926 0.52942137 0.14596237 0.06245313]
# [-0.25730074 -0.47057863  0.14596237  0.06245313]
#   Gradient for Weights: [0.05428025]
#   Gradient for Bias: -0.12986596938442824
#   Loss: 0.2889
# --------------------------------------------------
# Epoch 72
#   Weights: [-0.95304543]
#   Bias: 1.085932853248996
#   Z: [ 1.07303218  0.12538016 -1.76992389 -2.71757592]
#  actual[1 1 0 0]
#   Predictions: [0.74517313 0.53130404 0.14555179 0.06194417]
# [-0.25482687 -0.46869596  0.14555179  0.06194417]
#   Gradient for Weights: [0.05393403]
#   Gradient for Bias: -0.12900671677836492
#   Loss: 0.2870
# --------------------------------------------------
# Epoch 73
#   Weights: [-0.9584048]
#   Bias: 1.098748486775412
#   Z: [ 1.08593285  0.13288743 -1.77320343 -2.72624886]
#  actual[1 1 0 0]
#   Predictions: [0.74761508 0.53317305 0.1451444  0.06144212]
# [-0.25238492 -0.46682695  0.1451444   0.06144212]
#   Gradient for Weights: [0.05359369]
#   Gradient for Bias: -0.1281563352641601
#   Loss: 0.2850
# --------------------------------------------------
# Epoch 74
#   Weights: [-0.96373069]
#   Bias: 1.1114799652812257
#   Z: [ 1.09874849  0.14034369 -1.7764659  -2.7348707 ]
#  actual[1 1 0 0]
#   Predictions: [0.75002554 0.53502845 0.14474007 0.0609468 ]
# [-0.24997446 -0.46497155  0.14474007  0.0609468 ]
#   Gradient for Weights: [0.05325897]
#   Gradient for Bias: -0.12731478505813765
#   Loss: 0.2831
# --------------------------------------------------
# Epoch 75
#   Weights: [-0.96902366]
#   Bias: 1.1241281672765309
#   Z: [ 1.11147997  0.14774927 -1.77971212 -2.74344281]
#  actual[1 1 0 0]
#   Predictions: [0.75240492 0.53687027 0.14433869 0.06045805]
# [-0.24759508 -0.46312973  0.14433869  0.06045805]
#   Gradient for Weights: [0.05292963]
#   Gradient for Bias: -0.1264820199530507
#   Loss: 0.2812
# --------------------------------------------------
# Epoch 76
#   Weights: [-0.9742842]
#   Bias: 1.136693966076494
#   Z: [ 1.12412817  0.15510451 -1.7829428  -2.75196646]
#  actual[1 1 0 0]
#   Predictions: [0.75475365 0.53869858 0.14394014 0.05997569]
# [-0.24524635 -0.46130142  0.14394014  0.05997569]
#   Gradient for Weights: [0.05260544]
#   Gradient for Bias: -0.12565798799963263
#   Loss: 0.2793
# --------------------------------------------------
# Epoch 77
#   Weights: [-0.97951282]
#   Bias: 1.1491782292892454
#   Z: [ 1.13669397  0.16240977 -1.78615864 -2.76044284]
#  actual[1 1 0 0]
#   Predictions: [0.75707213 0.54051343 0.14354433 0.05949958]
# [-0.24292787 -0.45948657  0.14354433  0.05949958]
#   Gradient for Weights: [0.05228619]
#   Gradient for Bias: -0.12484263212751252
#   Loss: 0.2775
# --------------------------------------------------
# Epoch 78
#   Weights: [-0.98470999]
#   Bias: 1.161581818360344
#   Z: [ 1.14917823  0.16966541 -1.78936023 -2.76887305]
#  actual[1 1 0 0]
#   Predictions: [0.75936079 0.54231489 0.14315118 0.05902958]
# [-0.24063921 -0.45768511  0.14315118  0.05902958]
#   Gradient for Weights: [0.05197169]
#   Gradient for Bias: -0.12403589071098618
#   Loss: 0.2756
# --------------------------------------------------
# Epoch 79
#   Weights: [-0.98987616]
#   Bias: 1.1739055881688052
#   Z: [ 1.16158182  0.17687183 -1.79254814 -2.77725813]
#  actual[1 1 0 0]
#   Predictions: [0.76162002 0.54410304 0.1427606  0.05856555]
# [-0.23837998 -0.45589696  0.1427606   0.05856555]
#   Gradient for Weights: [0.05166176]
#   Gradient for Bias: -0.12323769808461206
#   Loss: 0.2738
# --------------------------------------------------
# Epoch 80
#   Weights: [-0.99501179]
#   Bias: 1.1861503866701173
#   Z: [ 1.17390559  0.18402942 -1.7957229  -2.78559907]
#  actual[1 1 0 0]
#   Predictions: [0.76385024 0.54587795 0.14237251 0.05810735]
# [-0.23614976 -0.45412205  0.14237251  0.05810735]
#   Gradient for Weights: [0.05135623]
#   Gradient for Bias: -0.12244798501312215
#   Loss: 0.2720
# --------------------------------------------------
# Epoch 81
#   Weights: [-1.00011728]
#   Bias: 1.1983170545820891
#   Z: [ 1.18615039  0.1911386  -1.79888497 -2.79389676]
#  actual[1 1 0 0]
#   Predictions: [0.76605186 0.5476397  0.14198685 0.05765488]
# [-0.23394814 -0.4523603   0.14198685  0.05765488]
#   Gradient for Weights: [0.05105494]
#   Gradient for Bias: -0.12166667911971767
#   Loss: 0.2703
# --------------------------------------------------
# Epoch 82
#   Weights: [-1.00519305]
#   Bias: 1.2104064251097326
#   Z: [ 1.19831705  0.19819977 -1.80203478 -2.80215206]
#  actual[1 1 0 0]
#   Predictions: [0.76822526 0.54938837 0.14160355 0.05720799]
# [-0.23177474 -0.45061163  0.14160355  0.05720799]
#   Gradient for Weights: [0.05075775]
#   Gradient for Bias: -0.12089370527643434
#   Loss: 0.2686
# --------------------------------------------------
# Epoch 83
#   Weights: [-1.01023951]
#   Bias: 1.2224193237057248
#   Z: [ 1.21040643  0.20521337 -1.80517274 -2.81036579]
#  actual[1 1 0 0]
#   Predictions: [0.77037085 0.55112405 0.14122256 0.05676659]
# [-0.22962915 -0.44887595  0.14122256  0.05676659]
#   Gradient for Weights: [0.05046452]
#   Gradient for Bias: -0.1201289859599213
#   Loss: 0.2668
# --------------------------------------------------
# Epoch 84
#   Weights: [-1.01525702]
#   Bias: 1.2343565678632913
#   Z: [ 1.22241932  0.21217982 -1.8082992  -2.8185387 ]
#  actual[1 1 0 0]
#   Predictions: [0.77248903 0.55284684 0.14084381 0.05633056]
# [-0.22751097 -0.44715316  0.14084381  0.05633056]
#   Gradient for Weights: [0.05017513]
#   Gradient for Bias: -0.11937244157566515
#   Loss: 0.2651
# --------------------------------------------------
# Epoch 85
#   Weights: [-1.02024596]
#   Bias: 1.2462189669386328
#   Z: [ 1.23435657  0.21909955 -1.81141449 -2.82667151]
#  actual[1 1 0 0]
#   Predictions: [0.77458017 0.55455681 0.14046726 0.0558998 ]
# [-0.22541983 -0.44544319  0.14046726  0.0558998 ]
#   Gradient for Weights: [0.04988945]
#   Gradient for Bias: -0.11862399075341548
#   Loss: 0.2635
# --------------------------------------------------
# Epoch 86
#   Weights: [-1.0252067]
#   Bias: 1.258007322000264
#   Z: [ 1.24621897  0.225973   -1.81451893 -2.83476489]
#  actual[1 1 0 0]
#   Predictions: [0.77664466 0.55625408 0.14009286 0.0554742 ]
# [-0.22335534 -0.44374592  0.14009286  0.0554742 ]
#   Gradient for Weights: [0.04960737]
#   Gradient for Bias: -0.11788355061631349
#   Loss: 0.2618
# --------------------------------------------------
# Epoch 87
#   Weights: [-1.03013958]
#   Bias: 1.269722425702864
#   Z: [ 1.25800732  0.23280062 -1.81761278 -2.84281948]
#  actual[1 1 0 0]
#   Predictions: [0.77868289 0.55793872 0.13972057 0.05505368]
# [-0.22131711 -0.44206128  0.13972057  0.05505368]
#   Gradient for Weights: [0.04932878]
#   Gradient for Bias: -0.11715103702600056
#   Loss: 0.2602
# --------------------------------------------------
# Epoch 88
#   Weights: [-1.03504494]
#   Bias: 1.2813650621834418
#   Z: [ 1.26972243  0.23958285 -1.82069631 -2.85083589]
#  actual[1 1 0 0]
#   Predictions: [0.78069523 0.55961085 0.13935034 0.05463812]
# [-0.21930477 -0.44038915  0.13935034  0.05463812]
#   Gradient for Weights: [0.04905359]
#   Gradient for Bias: -0.11642636480577773
#   Loss: 0.2586
# --------------------------------------------------
# Epoch 89
#   Weights: [-1.03992311]
#   Bias: 1.2929360069778117
#   Z: [ 1.28136506  0.24632012 -1.82376975 -2.85881469]
#  actual[1 1 0 0]
#   Predictions: [0.78268205 0.56127055 0.13898215 0.05422746]
# [-0.21731795 -0.43872945  0.13898215  0.05422746]
#   Gradient for Weights: [0.04878171]
#   Gradient for Bias: -0.11570944794369943
#   Loss: 0.2570
# --------------------------------------------------
# Epoch 90
#   Weights: [-1.04477441]
#   Bias: 1.304436026955544
#   Z: [ 1.29293601  0.2530129  -1.82683332 -2.86675643]
#  actual[1 1 0 0]
#   Predictions: [0.78464372 0.56291794 0.13861595 0.05382159]
# [-0.21535628 -0.43708206  0.13861595  0.05382159]
#   Gradient for Weights: [0.04851304]
#   Gradient for Bias: -0.115000199777322
#   Loss: 0.2554
# --------------------------------------------------
# Epoch 91
#   Weights: [-1.04959916]
#   Bias: 1.3158658802717107
#   Z: [ 1.30443603  0.25966161 -1.82988721 -2.87466163]
#  actual[1 1 0 0]
#   Predictions: [0.78658061 0.56455311 0.13825171 0.05342044]
# [-0.21341939 -0.43544689  0.13825171  0.05342044]
#   Gradient for Weights: [0.0482475]
#   Gradient for Bias: -0.1142985331616684
#   Loss: 0.2539
# --------------------------------------------------
# Epoch 92
#   Weights: [-1.05439766]
#   Bias: 1.3272263163338947
#   Z: [ 1.31586588  0.26626672 -1.83293161 -2.88253077]
#  actual[1 1 0 0]
#   Predictions: [0.78849307 0.56617616 0.13788941 0.05302392]
# [-0.21150693 -0.43382384  0.13788941  0.05302392]
#   Gradient for Weights: [0.04798501]
#   Gradient for Bias: -0.11360436062183916
#   Loss: 0.2523
# --------------------------------------------------
# Epoch 93
#   Weights: [-1.05917021]
#   Bias: 1.3385180757830517
#   Z: [ 1.32722632  0.27282865 -1.83596668 -2.89036434]
#  actual[1 1 0 0]
#   Predictions: [0.79038146 0.5677872  0.13752901 0.05263195]
# [-0.20961854 -0.4322128   0.13752901  0.05263195]
#   Gradient for Weights: [0.0477255]
#   Gradient for Bias: -0.11291759449157021
#   Loss: 0.2508
# --------------------------------------------------
# Epoch 94
#   Weights: [-1.0639171]
#   Bias: 1.3497418904869445
#   Z: [ 1.33851808  0.27934786 -1.83899257 -2.89816278]
#  actual[1 1 0 0]
#   Predictions: [0.79224613 0.56938634 0.13717048 0.05224446]
# [-0.20775387 -0.43061366  0.13717048  0.05224446]
#   Gradient for Weights: [0.0474689]
#   Gradient for Bias: -0.11223814703892673
#   Loss: 0.2493
# --------------------------------------------------
# Epoch 95
#   Weights: [-1.06863862]
#   Bias: 1.3608984835449662
#   Z: [ 1.34974189  0.28582479 -1.84200942 -2.90592653]
#  actual[1 1 0 0]
#   Predictions: [0.79408743 0.57097367 0.13681381 0.05186137]
# [-0.20591257 -0.42902633  0.13681381  0.05186137]
#   Gradient for Weights: [0.04721515]
#   Gradient for Bias: -0.11156593058021816
#   Loss: 0.2478
# --------------------------------------------------
# Epoch 96
#   Weights: [-1.07333504]
#   Bias: 1.371988569303279
#   Z: [ 1.36089848  0.29225986 -1.84501737 -2.91365599]
#  actual[1 1 0 0]
#   Predictions: [0.79590569 0.57254929 0.13645898 0.05148261]
# [-0.20409431 -0.42745071  0.13645898  0.05148261]
#   Gradient for Weights: [0.04696417]
#   Gradient for Bias: -0.11090085758312684
#   Loss: 0.2464
# --------------------------------------------------
# Epoch 97
#   Weights: [-1.07800663]
#   Bias: 1.3830128533792745
#   Z: [ 1.37198857  0.29865353 -1.84801654 -2.92135158]
#  actual[1 1 0 0]
#   Predictions: [0.79770125 0.57411333 0.13610595 0.05110812]
# [-0.20229875 -0.42588667  0.13610595  0.05110812]
#   Gradient for Weights: [0.04671591]
#   Gradient for Bias: -0.11024284075995613
#   Loss: 0.2449
# --------------------------------------------------
# Epoch 98
#   Weights: [-1.08265366]
#   Bias: 1.3939720326944574
#   Z: [ 1.38301285  0.30500623 -1.85100703 -2.92901365]
#  actual[1 1 0 0]
#   Predictions: [0.79947444 0.57566587 0.1357547  0.05073781]
# [-0.20052556 -0.42433413  0.1357547   0.05073781]
#   Gradient for Weights: [0.04647031]
#   Gradient for Bias: -0.10959179315182763
#   Loss: 0.2435
# --------------------------------------------------
# Epoch 99
#   Weights: [-1.08727639]
#   Bias: 1.404866795514916
#   Z: [ 1.39397203  0.31131838 -1.85398894 -2.9366426 ]
#  actual[1 1 0 0]
#   Predictions: [0.8012256  0.57720703 0.13540523 0.05037163]
# [-0.1987744  -0.42279297  0.13540523  0.05037163]
#   Gradient for Weights: [0.04622731]
#   Gradient for Bias: -0.10894762820458584
#   Loss: 0.2421
# --------------------------------------------------
# Epoch 100
#   Weights: [-1.09187508]
#   Bias: 1.4156978214986264
#   Z: [ 1.4048668   0.31759041 -1.85696237 -2.94423876]
#  actual[1 1 0 0]
#   Predictions: [0.80295504 0.5787369  0.13505751 0.05000951]
# [-0.19704496 -0.4212631   0.13505751  0.05000951]
#   Gradient for Weights: [0.04598687]
#   Gradient for Bias: -0.10831025983710495
#   Loss: 0.2407
# --------------------------------------------------
# Epoch 101
#   Weights: [-1.09644997]
#   Bias: 1.4264657817488897
#   Z: [ 1.41569782  0.32382275 -1.8599274  -2.95180248]
#  actual[1 1 0 0]
#   Predictions: [0.80466308 0.5802556  0.13471151 0.04965139]
# [-0.19533692 -0.4197444   0.13471151  0.04965139]
#   Gradient for Weights: [0.04574893]
#   Gradient for Bias: -0.10767960250263192
#   Loss: 0.2393
# --------------------------------------------------
# Epoch 102
#   Weights: [-1.10100131]
#   Bias: 1.4371713388732648
#   Z: [ 1.42646578  0.33001581 -1.86288412 -2.95933409]
#  actual[1 1 0 0]
#   Predictions: [0.80635005 0.58176322 0.13436724 0.04929721]
# [-0.19364995 -0.41823678  0.13436724  0.04929721]
#   Gradient for Weights: [0.04551344]
#   Gradient for Bias: -0.10705557124375077
#   Loss: 0.2379
# --------------------------------------------------
# Epoch 103
#   Weights: [-1.10552935]
#   Bias: 1.4478151470474148
#   Z: [ 1.43717134  0.33617003 -1.8658326  -2.96683391]
#  actual[1 1 0 0]
#   Predictions: [0.80801623 0.58325988 0.13402466 0.0489469 ]
# [-0.19198377 -0.41674012  0.13402466  0.0489469 ]
#   Gradient for Weights: [0.04528036]
#   Gradient for Bias: -0.10643808174149898
#   Loss: 0.2366
# --------------------------------------------------
# Epoch 104
#   Weights: [-1.11003431]
#   Bias: 1.4583978520833274
#   Z: [ 1.44781515  0.3422858  -1.8687729  -2.97430225]
#  actual[1 1 0 0]
#   Predictions: [0.80966196 0.58474566 0.13368377 0.04860041]
# [-0.19033804 -0.41525434  0.13368377  0.04860041]
#   Gradient for Weights: [0.04504965]
#   Gradient for Bias: -0.10582705035912601
#   Loss: 0.2353
# --------------------------------------------------
# Epoch 105
#   Weights: [-1.11451644]
#   Bias: 1.4689200915014218
#   Z: [ 1.45839785  0.34836354 -1.87170509 -2.9817394 ]
#  actual[1 1 0 0]
#   Predictions: [0.81128751 0.58622069 0.13334455 0.04825768]
# [-0.18871249 -0.41377931  0.13334455  0.04825768]
#   Gradient for Weights: [0.04482126]
#   Gradient for Bias: -0.10522239418094358
#   Loss: 0.2339
# --------------------------------------------------
# Epoch 106
#   Weights: [-1.11897596]
#   Bias: 1.4793824946060894
#   Z: [ 1.46892009  0.35440365 -1.87462923 -2.98914567]
#  actual[1 1 0 0]
#   Predictions: [0.81289319 0.58768504 0.13300699 0.04791865]
# [-0.18710681 -0.41231496  0.13300699  0.04791865]
#   Gradient for Weights: [0.04459516]
#   Gradient for Bias: -0.10462403104667665
#   Loss: 0.2326
# --------------------------------------------------
# Epoch 107
#   Weights: [-1.12341308]
#   Bias: 1.4897856825642588
#   Z: [ 1.47938249  0.36040654 -1.87754537 -2.99652133]
#  actual[1 1 0 0]
#   Predictions: [0.81447929 0.58913884 0.13267107 0.04758328]
# [-0.18552071 -0.41086116  0.13267107  0.04758328]
#   Gradient for Weights: [0.04437129]
#   Gradient for Bias: -0.10403187958169434
#   Loss: 0.2313
# --------------------------------------------------
# Epoch 108
#   Weights: [-1.12782805]
#   Bias: 1.5001302684866054
#   Z: [ 1.48978568  0.3663726  -1.88045357 -3.00386665]
#  actual[1 1 0 0]
#   Predictions: [0.8160461  0.59058218 0.13233678 0.0472515 ]
# [-0.1839539  -0.40941782  0.13233678  0.0472515 ]
#   Gradient for Weights: [0.04414963]
#   Gradient for Bias: -0.10344585922346658
#   Loss: 0.2301
# --------------------------------------------------
# Epoch 109
#   Weights: [-1.13222106]
#   Bias: 1.5104168575110617
#   Z: [ 1.50013027  0.37230222 -1.88335387 -3.01118192]
#  actual[1 1 0 0]
#   Predictions: [0.8175939  0.59201516 0.13200412 0.04692326]
# [-0.1824061  -0.40798484  0.13200412  0.04692326]
#   Gradient for Weights: [0.04393014]
#   Gradient for Bias: -0.102865890244564
#   Loss: 0.2288
# --------------------------------------------------
# Epoch 110
#   Weights: [-1.13659234]
#   Bias: 1.5206460468883112
#   Z: [ 1.51041686  0.3781958  -1.88624633 -3.01846739]
#  actual[1 1 0 0]
#   Predictions: [0.81912298 0.59343788 0.13167305 0.04659852]
# [-0.18087702 -0.40656212  0.13167305  0.04659852]
#   Gradient for Weights: [0.04371278]
#   Gradient for Bias: -0.10229189377249397
#   Loss: 0.2276
# --------------------------------------------------
# Epoch 111
#   Weights: [-1.14094209]
#   Bias: 1.5308184260689752
#   Z: [ 1.52064605  0.38405371 -1.88913097 -3.02572331]
#  actual[1 1 0 0]
#   Predictions: [0.82063359 0.59485043 0.13134359 0.04627722]
# [-0.17936641 -0.40514957  0.13134359  0.04627722]
#   Gradient for Weights: [0.04349752]
#   Gradient for Bias: -0.1017237918066405
#   Loss: 0.2263
# --------------------------------------------------
# Epoch 112
#   Weights: [-1.14527052]
#   Bias: 1.5409345767922307
#   Z: [ 1.53081843  0.38987634 -1.89200784 -3.03294993]
#  actual[1 1 0 0]
#   Predictions: [0.82212603 0.59625293 0.13101571 0.04595931]
# [-0.17787397 -0.40374707  0.13101571  0.04595931]
#   Gradient for Weights: [0.04328432]
#   Gradient for Bias: -0.10116150723255388
#   Loss: 0.2251
# --------------------------------------------------
# Epoch 113
#   Weights: [-1.14957784]
#   Bias: 1.5509950731756126
#   Z: [ 1.54093458  0.39566405 -1.89487699 -3.04014751]
#  actual[1 1 0 0]
#   Predictions: [0.82360054 0.59764546 0.1306894  0.04564474]
# [-0.17639946 -0.40235454  0.1306894   0.04564474]
#   Gradient for Weights: [0.04307316]
#   Gradient for Bias: -0.10060496383381805
#   Loss: 0.2239
# --------------------------------------------------
# Epoch 114
#   Weights: [-1.15386424]
#   Bias: 1.5610004818057828
#   Z: [ 1.55099507  0.40141724 -1.89773844 -3.04731628]
#  actual[1 1 0 0]
#   Predictions: [0.8250574  0.59902812 0.13036465 0.04533348]
# [-0.1749426  -0.40097188  0.13036465  0.04533348]
#   Gradient for Weights: [0.042864]
#   Gradient for Bias: -0.10005408630170205
#   Loss: 0.2227
# --------------------------------------------------
# Epoch 115
#   Weights: [-1.15812992]
#   Bias: 1.5709513618300617
#   Z: [ 1.56100048  0.40713624 -1.90059223 -3.05445647]
#  actual[1 1 0 0]
#   Predictions: [0.82649687 0.60040101 0.13004146 0.04502546]
# [-0.17350313 -0.39959899  0.13004146  0.04502546]
#   Gradient for Weights: [0.04265681]
#   Gradient for Bias: -0.09950880024278849
#   Loss: 0.2215
# --------------------------------------------------
# Epoch 116
#   Weights: [-1.16237508]
#   Bias: 1.5808482650485371
#   Z: [ 1.57095136  0.41282144 -1.90343839 -3.06156831]
#  actual[1 1 0 0]
#   Predictions: [0.82791919 0.60176421 0.12971981 0.04472066]
# [-0.17208081 -0.39823579  0.12971981  0.04472066]
#   Gradient for Weights: [0.04245157]
#   Gradient for Bias: -0.09896903218475381
#   Loss: 0.2204
# --------------------------------------------------
# Epoch 117
#   Weights: [-1.1665999]
#   Bias: 1.5906917360065835
#   Z: [ 1.58084827  0.41847319 -1.90627696 -3.06865204]
#  actual[1 1 0 0]
#   Predictions: [0.82932462 0.60311784 0.12939969 0.04441901]
# [-0.17067538 -0.39688216  0.12939969  0.04441901]
#   Gradient for Weights: [0.04224824]
#   Gradient for Bias: -0.09843470958046342
#   Loss: 0.2192
# --------------------------------------------------
# Epoch 118
#   Weights: [-1.17080458]
#   Bias: 1.6004823120876366
#   Z: [ 1.59069174  0.42409184 -1.90910796 -3.07570786]
#  actual[1 1 0 0]
#   Predictions: [0.8307134  0.60446197 0.1290811  0.04412048]
# [-0.1692866  -0.39553803  0.1290811   0.04412048]
#   Gradient for Weights: [0.0420468]
#   Gradient for Bias: -0.09790576081052939
#   Loss: 0.2181
# --------------------------------------------------
# Epoch 119
#   Weights: [-1.1749893]
#   Bias: 1.6102205236060834
#   Z: [ 1.60048231  0.42967773 -1.91193142 -3.082736  ]
#  actual[1 1 0 0]
#   Predictions: [0.83208578 0.60579671 0.12876402 0.04382502]
# [-0.16791422 -0.39420329  0.12876402  0.04382502]
#   Gradient for Weights: [0.04184722]
#   Gradient for Bias: -0.09738211518446806
#   Loss: 0.2169
# --------------------------------------------------
# Epoch 120
#   Weights: [-1.17915425]
#   Bias: 1.6199068939001418
#   Z: [ 1.61022052  0.43523122 -1.91474738 -3.08973668]
#  actual[1 1 0 0]
#   Predictions: [0.833442   0.60712214 0.12844845 0.0435326 ]
# [-0.166558   -0.39287786  0.12844845  0.0435326 ]
#   Gradient for Weights: [0.04164947]
#   Gradient for Bias: -0.09686370294058443
#   Loss: 0.2158
# --------------------------------------------------
# Epoch 121
#   Weights: [-1.1832996]
#   Bias: 1.6295419394246116
#   Z: [ 1.61990689  0.44075265 -1.91755585 -3.0967101 ]
#  actual[1 1 0 0]
#   Predictions: [0.83478229 0.60843836 0.12813437 0.04324316]
# [-0.16521771 -0.39156164  0.12813437  0.04324316]
#   Gradient for Weights: [0.04145353]
#   Gradient for Bias: -0.09635045524469775
#   Loss: 0.2147
# --------------------------------------------------
# Epoch 122
#   Weights: [-1.18742554]
#   Bias: 1.6391261698433932
#   Z: [ 1.62954194  0.44624234 -1.92035686 -3.10365646]
#  actual[1 1 0 0]
#   Predictions: [0.83610688 0.60974545 0.12782178 0.04295668]
# [-0.16389312 -0.39025455  0.12782178  0.04295668]
#   Gradient for Weights: [0.04125938]
#   Gradient for Bias: -0.0958423041878162
#   Loss: 0.2136
# --------------------------------------------------
# Epoch 123
#   Weights: [-1.19153224]
#   Bias: 1.648660088121679
#   Z: [ 1.63912617  0.45170063 -1.92315044 -3.11057598]
#  actual[1 1 0 0]
#   Predictions: [0.837416   0.6110435  0.12751066 0.04267311]
# [-0.162584   -0.3889565   0.12751066  0.04267311]
#   Gradient for Weights: [0.04106698]
#   Gradient for Bias: -0.09533918278285858
# ...
#   Bias: 4.697076164403941
#   Z: [ 4.69528904  2.09909739 -3.09328591 -5.68947756]
#  actual[1 1 0 0]
#   Predictions: [0.99094453 0.89081542 0.04338506 0.00336996]
# [-0.00905547 -0.10918458  0.04338506  0.00336996]
#   Gradient for Weights: [0.00861261]
#   Gradient for Bias: -0.017871259100083966
#   Loss: 0.0431
# --------------------------------------------------
# Epoch 960
#   Weights: [-2.59791339]
#   Bias: 4.698861604624513
#   Z: [ 4.69707616  2.10002325 -3.09408257 -5.69113548]
#  actual[1 1 0 0]
#   Predictions: [0.99096055 0.89090544 0.043352   0.0033644 ]
# [-0.00903945 -0.10909456  0.043352    0.0033644 ]
#   Gradient for Weights: [0.00860476]
#   Gradient for Bias: -0.017854402205716383
#   Loss: 0.0431
# --------------------------------------------------
# Epoch 961
#   Weights: [-2.59877308]
#   Bias: 4.700645362406756
#   Z: [ 4.6988616   2.10094822 -3.09487856 -5.69279195]
#  actual[1 1 0 0]
#   Predictions: [0.99097653 0.89099531 0.043319   0.00335885]
# [-0.00902347 -0.10900469  0.043319    0.00335885]
#   Gradient for Weights: [0.00859693]
#   Gradient for Bias: -0.01783757782243024
#   Loss: 0.0430
# --------------------------------------------------
# Epoch 962
#   Weights: [-2.59963199]
#   Bias: 4.70242744099227
#   Z: [ 4.70064536  2.10187228 -3.09567388 -5.69444696]
#  actual[1 1 0 0]
#   Predictions: [0.99099246 0.89108502 0.04328606 0.00335331]
# [-0.00900754 -0.10891498  0.04328606  0.00335331]
#   Gradient for Weights: [0.00858911]
#   Gradient for Bias: -0.017820785855143496
#   Loss: 0.0430
# --------------------------------------------------
# Epoch 963
#   Weights: [-2.60049012]
#   Bias: 4.704207843613185
#   Z: [ 4.70242744  2.10279545 -3.09646854 -5.69610053]
#  actual[1 1 0 0]
#   Predictions: [0.99100836 0.89117458 0.04325316 0.00334779]
# [-0.00899164 -0.10882542  0.04325316  0.00334779]
#   Gradient for Weights: [0.00858131]
#   Gradient for Bias: -0.01780402620914687
#   Loss: 0.0430
# --------------------------------------------------
# Epoch 964
#   Weights: [-2.60134748]
#   Bias: 4.705986573492195
#   Z: [ 4.70420784  2.10371772 -3.09726253 -5.69775265]
#  actual[1 1 0 0]
#   Predictions: [0.99102421 0.891264   0.04322031 0.00334229]
# [-0.00897579 -0.108736    0.04322031  0.00334229]
#   Gradient for Weights: [0.00857352]
#   Gradient for Bias: -0.017787298790102043
#   Loss: 0.0429
# --------------------------------------------------
# Epoch 965
#   Weights: [-2.60220405]
#   Bias: 4.7077636338426
#   Z: [ 4.70598657  2.1046391  -3.09805585 -5.69940333]
#  actual[1 1 0 0]
#   Predictions: [0.99104002 0.89135326 0.04318752 0.00333679]
# [-0.00895998 -0.10864674  0.04318752  0.00333679]
#   Gradient for Weights: [0.00856575]
#   Gradient for Bias: -0.01777060350403955
#   Loss: 0.0429
# --------------------------------------------------
# Epoch 966
#   Weights: [-2.60305985]
#   Bias: 4.709539027868336
#   Z: [ 4.70776363  2.10555958 -3.09884852 -5.70105256]
#  actual[1 1 0 0]
#   Predictions: [0.99105578 0.89144237 0.04315478 0.00333131]
# [-0.00894422 -0.10855763  0.04315478  0.00333131]
#   Gradient for Weights: [0.00855799]
#   Gradient for Bias: -0.017753940257357437
#   Loss: 0.0428
# --------------------------------------------------
# Epoch 967
#   Weights: [-2.60391487]
#   Bias: 4.711312758764017
#   Z: [ 4.70953903  2.10647918 -3.09964052 -5.70270037]
#  actual[1 1 0 0]
#   Predictions: [0.99107151 0.89153133 0.04312209 0.00332584]
# [-0.00892849 -0.10846867  0.04312209  0.00332584]
#   Gradient for Weights: [0.00855024]
#   Gradient for Bias: -0.017737308956819138
#   Loss: 0.0428
# --------------------------------------------------
# Epoch 968
#   Weights: [-2.60476912]
#   Bias: 4.713084829714973
#   Z: [ 4.71131276  2.10739789 -3.10043186 -5.70434673]
#  actual[1 1 0 0]
#   Predictions: [0.99108719 0.89162014 0.04308944 0.00332039]
# [-0.00891281 -0.10837986  0.04308944  0.00332039]
#   Gradient for Weights: [0.00854251]
#   Gradient for Bias: -0.01772070950955205
#   Loss: 0.0428
# --------------------------------------------------
# Epoch 969
#   Weights: [-2.6056226]
#   Bias: 4.7148552438972775
#   Z: [ 4.71308483  2.10831571 -3.10122254 -5.70599166]
#  actual[1 1 0 0]
#   Predictions: [0.99110283 0.8917088  0.04305685 0.00331495]
# [-0.00889717 -0.1082912   0.04305685  0.00331495]
#   Gradient for Weights: [0.00853479]
#   Gradient for Bias: -0.017704141823045035
#   Loss: 0.0427
# --------------------------------------------------
# Epoch 970
#   Weights: [-2.60647531]
#   Bias: 4.716624004477792
#   Z: [ 4.71485524  2.10923264 -3.10201256 -5.70763517]
#  actual[1 1 0 0]
#   Predictions: [0.99111843 0.89179731 0.04302431 0.00330953]
# [-0.00888157 -0.10820269  0.04302431  0.00330953]
#   Gradient for Weights: [0.00852709]
#   Gradient for Bias: -0.017687605805147534
#   Loss: 0.0427
# --------------------------------------------------
# Epoch 971
#   Weights: [-2.60732725]
#   Bias: 4.718391114614199
#   Z: [ 4.716624    2.11014869 -3.10280193 -5.70927724]
#  actual[1 1 0 0]
#   Predictions: [0.99113398 0.89188567 0.04299183 0.00330411]
# [-0.00886602 -0.10811433  0.04299183  0.00330411]
#   Gradient for Weights: [0.0085194]
#   Gradient for Bias: -0.017671101364067077
#   Loss: 0.0426
# --------------------------------------------------
# Epoch 972
#   Weights: [-2.60817842]
#   Bias: 4.720156577455035
#   Z: [ 4.71839111  2.11106386 -3.10359064 -5.71091789]
#  actual[1 1 0 0]
#   Predictions: [0.9911495  0.89197389 0.04295939 0.00329872]
# [-0.0088505  -0.10802611  0.04295939  0.00329872]
#   Gradient for Weights: [0.00851173]
#   Gradient for Bias: -0.017654628408368105
#   Loss: 0.0426
# --------------------------------------------------
# Epoch 973
#   Weights: [-2.60902883]
#   Bias: 4.7219203961397325
#   Z: [ 4.72015658  2.11197815 -3.1043787  -5.71255712]
#  actual[1 1 0 0]
#   Predictions: [0.99116497 0.89206195 0.042927   0.00329333]
# [-0.00883503 -0.10793805  0.042927    0.00329333]
#   Gradient for Weights: [0.00850407]
#   Gradient for Bias: -0.01763818684696986
#   Loss: 0.0426
# --------------------------------------------------
# Epoch 974
#   Weights: [-2.60987847]
#   Bias: 4.723682573798647
#   Z: [ 4.7219204   2.11289156 -3.1051661  -5.71419493]
#  actual[1 1 0 0]
#   Predictions: [0.9911804  0.89214987 0.04289466 0.00328796]
# [-0.0088196  -0.10785013  0.04289466  0.00328796]
#   Gradient for Weights: [0.00849642]
#   Gradient for Bias: -0.017621776589144697
#   Loss: 0.0425
# --------------------------------------------------
# Epoch 975
#   Weights: [-2.61072735]
#   Bias: 4.725443113553099
#   Z: [ 4.72368257  2.1138041  -3.10595285 -5.71583132]
#  actual[1 1 0 0]
#   Predictions: [0.99119579 0.89223764 0.04286237 0.0032826 ]
# [-0.00880421 -0.10776236  0.04286237  0.0032826 ]
#   Gradient for Weights: [0.00848879]
#   Gradient for Bias: -0.017605397544516555
#   Loss: 0.0425
# --------------------------------------------------
# Epoch 976
#   Weights: [-2.61157547]
#   Bias: 4.7272020185154044
#   Z: [ 4.72544311  2.11471576 -3.10673894 -5.7174663 ]
#  actual[1 1 0 0]
#   Predictions: [0.99121114 0.89232527 0.04283013 0.00327726]
# [-0.00878886 -0.10767473  0.04283013  0.00327726]
#   Gradient for Weights: [0.00848117]
#   Gradient for Bias: -0.017589049623059218
#   Loss: 0.0425
# --------------------------------------------------
# Epoch 977
#   Weights: [-2.61242283]
#   Bias: 4.728959291788914
#   Z: [ 4.72720202  2.11562655 -3.10752439 -5.71909986]
#  actual[1 1 0 0]
#   Predictions: [0.99122645 0.89241274 0.04279795 0.00327192]
# [-0.00877355 -0.10758726  0.04279795  0.00327192]
#   Gradient for Weights: [0.00847357]
#   Gradient for Bias: -0.017572732735094486
#   Loss: 0.0424
# --------------------------------------------------
# Epoch 978
#   Weights: [-2.61326942]
#   Bias: 4.7307149364680425
#   Z: [ 4.72895929  2.11653647 -3.10830919 -5.72073202]
#  actual[1 1 0 0]
#   Predictions: [0.99124172 0.89250008 0.04276581 0.00326661]
# [-0.00875828 -0.10749992  0.04276581  0.00326661]
#   Gradient for Weights: [0.00846598]
#   Gradient for Bias: -0.017556446791290394
#   Loss: 0.0424
# --------------------------------------------------
# Epoch 979
#   Weights: [-2.61411527]
#   Bias: 4.732468955638309
#   Z: [ 4.73071494  2.11744551 -3.10909334 -5.72236276]
#  actual[1 1 0 0]
#   Predictions: [0.99125695 0.89258726 0.04273372 0.0032613 ]
# [-0.00874305 -0.10741274  0.04273372  0.0032613 ]
#   Gradient for Weights: [0.0084584]
#   Gradient for Bias: -0.01754019170265988
#   Loss: 0.0423
# --------------------------------------------------
# Epoch 980
#   Weights: [-2.61496035]
#   Bias: 4.734221352376364
#   Z: [ 4.73246896  2.11835369 -3.10987684 -5.7239921 ]
#  actual[1 1 0 0]
#   Predictions: [0.99127214 0.8926743  0.04270168 0.00325601]
# [-0.00872786 -0.1073257   0.04270168  0.00325601]
#   Gradient for Weights: [0.00845084]
#   Gradient for Bias: -0.017523967380558787
#   Loss: 0.0423
# --------------------------------------------------
# Epoch 981
#   Weights: [-2.61580468]
#   Bias: 4.735972129750032
#   Z: [ 4.73422135  2.119261   -3.1106597  -5.72562005]
#  actual[1 1 0 0]
#   Predictions: [0.99128729 0.8927612  0.04266969 0.00325073]
# [-0.00871271 -0.1072388   0.04266969  0.00325073]
#   Gradient for Weights: [0.00844329]
#   Gradient for Bias: -0.017507773736684575
#   Loss: 0.0423
# --------------------------------------------------
# Epoch 982
#   Weights: [-2.61664825]
#   Bias: 4.73772129081834
#   Z: [ 4.73597213  2.12016745 -3.11144191 -5.72724659]
#  actual[1 1 0 0]
#   Predictions: [0.9913024  0.89284795 0.04263775 0.00324546]
# [-0.0086976  -0.10715205  0.04263775  0.00324546]
#   Gradient for Weights: [0.00843576]
#   Gradient for Bias: -0.017491610683074258
#   Loss: 0.0422
# --------------------------------------------------
# Epoch 983
#   Weights: [-2.61749108]
#   Bias: 4.73946883863155
#   Z: [ 4.73772129  2.12107304 -3.11222347 -5.72887173]
#  actual[1 1 0 0]
#   Predictions: [0.99131746 0.89293456 0.04260586 0.00324021]
# [-0.00868254 -0.10706544  0.04260586  0.00324021]
#   Gradient for Weights: [0.00842824]
#   Gradient for Bias: -0.017475478132102935
#   Loss: 0.0422
# --------------------------------------------------
# Epoch 984
#   Weights: [-2.61833315]
#   Bias: 4.741214776231199
#   Z: [ 4.73946884  2.12197776 -3.1130044  -5.73049548]
#  actual[1 1 0 0]
#   Predictions: [0.99133249 0.89302102 0.04257401 0.00323497]
# [-0.00866751 -0.10697898  0.04257401  0.00323497]
#   Gradient for Weights: [0.00842073]
#   Gradient for Bias: -0.01745937599648232
#   Loss: 0.0421
# --------------------------------------------------
# Epoch 985
#   Weights: [-2.61917448]
#   Bias: 4.742959106650124
#   Z: [ 4.74121478  2.12288162 -3.11378468 -5.73211783]
#  actual[1 1 0 0]
#   Predictions: [0.99134748 0.89310734 0.04254222 0.00322974]
# [-0.00865252 -0.10689266  0.04254222  0.00322974]
#   Gradient for Weights: [0.00841324]
#   Gradient for Bias: -0.017443304189258865
#   Loss: 0.0421
# --------------------------------------------------
# Epoch 986
#   Weights: [-2.62001505]
#   Bias: 4.744701832912505
#   Z: [ 4.74295911  2.12378463 -3.11456432 -5.7337388 ]
#  actual[1 1 0 0]
#   Predictions: [0.99136243 0.89319352 0.04251047 0.00322453]
# [-0.00863757 -0.10680648  0.04251047  0.00322453]
#   Gradient for Weights: [0.00840576]
#   Gradient for Bias: -0.0174272626238123
#   Loss: 0.0421
# --------------------------------------------------
# Epoch 987
#   Weights: [-2.62085488]
#   Bias: 4.7464429580338905
#   Z: [ 4.74470183  2.12468678 -3.11534333 -5.73535838]
#  actual[1 1 0 0]
#   Predictions: [0.99137734 0.89327955 0.04247878 0.00321933]
# [-0.00862266 -0.10672045  0.04247878  0.00321933]
#   Gradient for Weights: [0.0083983]
#   Gradient for Bias: -0.017411251213854194
#   Loss: 0.0420
# --------------------------------------------------
# Epoch 988
#   Weights: [-2.62169397]
#   Bias: 4.748182485021233
#   Z: [ 4.74644296  2.12558808 -3.11612169 -5.73697657]
#  actual[1 1 0 0]
#   Predictions: [0.99139221 0.89336544 0.04244713 0.00321414]
# [-0.00860779 -0.10663456  0.04244713  0.00321414]
#   Gradient for Weights: [0.00839084]
#   Gradient for Bias: -0.017395269873425802
#   Loss: 0.0420
# --------------------------------------------------
# Epoch 989
#   Weights: [-2.62253231]
#   Bias: 4.749920416872922
#   Z: [ 4.74818249  2.12648852 -3.11689942 -5.73859338]
#  actual[1 1 0 0]
#   Predictions: [0.99140704 0.89345119 0.04241553 0.00320896]
# [-0.00859296 -0.10654881  0.04241553  0.00320896]
#   Gradient for Weights: [0.00838341]
#   Gradient for Bias: -0.017379318516897255
#   Loss: 0.0420
# --------------------------------------------------
# Epoch 990
#   Weights: [-2.62336991]
#   Bias: 4.751656756578819
#   Z: [ 4.74992042  2.12738811 -3.11767651 -5.74020881]
#  actual[1 1 0 0]
#   Predictions: [0.99142184 0.8935368  0.04238398 0.0032038 ]
# [-0.00857816 -0.1064632   0.04238398  0.0032038 ]
#   Gradient for Weights: [0.00837598]
#   Gradient for Bias: -0.017363397058965235
#   Loss: 0.0419
# --------------------------------------------------
# Epoch 991
#   Weights: [-2.62420676]
#   Bias: 4.753391507120284
#   Z: [ 4.75165676  2.12828685 -3.11845296 -5.74182287]
#  actual[1 1 0 0]
#   Predictions: [0.99143659 0.89362226 0.04235247 0.00319865]
# [-0.00856341 -0.10637774  0.04235247  0.00319865]
#   Gradient for Weights: [0.00836857]
#   Gradient for Bias: -0.017347505414651986
#   Loss: 0.0419
# --------------------------------------------------
# Epoch 992
#   Weights: [-2.62504288]
#   Bias: 4.755124671470215
#   Z: [ 4.75339151  2.12918474 -3.11922878 -5.74343554]
#  actual[1 1 0 0]
#   Predictions: [0.99145131 0.89370759 0.04232102 0.00319351]
# [-0.00854869 -0.10629241  0.04232102  0.00319351]
#   Gradient for Weights: [0.00836117]
#   Gradient for Bias: -0.017331643499303485
#   Loss: 0.0419
# --------------------------------------------------
# Epoch 993
#   Weights: [-2.62587826]
#   Bias: 4.7568562525930735
#   Z: [ 4.75512467  2.13008179 -3.12000397 -5.74504685]
#  actual[1 1 0 0]
#   Predictions: [0.99146598 0.89379277 0.04228961 0.00318839]
# [-0.00853402 -0.10620723  0.04228961  0.00318839]
#   Gradient for Weights: [0.00835379]
#   Gradient for Bias: -0.01731581122858787
#   Loss: 0.0418
# --------------------------------------------------
# Epoch 994
#   Weights: [-2.6267129]
#   Bias: 4.758586253444923
#   Z: [ 4.75685625  2.13097799 -3.12077852 -5.74665678]
#  actual[1 1 0 0]
#   Predictions: [0.99148062 0.89387782 0.04225825 0.00318327]
# [-0.00851938 -0.10612218  0.04225825  0.00318327]
#   Gradient for Weights: [0.00834642]
#   Gradient for Bias: -0.017300008518494198
#   Loss: 0.0418
# --------------------------------------------------
# Epoch 995
#   Weights: [-2.62754681]
#   Bias: 4.760314676973456
#   Z: [ 4.75858625  2.13187335 -3.12155245 -5.74826535]
#  actual[1 1 0 0]
#   Predictions: [0.99149522 0.89396272 0.04222694 0.00317817]
# [-0.00850478 -0.10603728  0.04222694  0.00317817]
#   Gradient for Weights: [0.00833906]
#   Gradient for Bias: -0.017284235285330494
#   Loss: 0.0417
# --------------------------------------------------
# Epoch 996
#   Weights: [-2.62837998]
#   Bias: 4.762041526118028
#   Z: [ 4.76031468  2.13276787 -3.12232574 -5.74987255]
#  actual[1 1 0 0]
#   Predictions: [0.99150979 0.89404749 0.04219568 0.00317309]
# [-0.00849021 -0.10595251  0.04219568  0.00317309]
#   Gradient for Weights: [0.00833171]
#   Gradient for Bias: -0.017268491445722383
#   Loss: 0.0417
# --------------------------------------------------
# Epoch 997
#   Weights: [-2.62921242]
#   Bias: 4.763766803809689
#   Z: [ 4.76204153  2.13366155 -3.12309841 -5.75147839]
#  actual[1 1 0 0]
#   Predictions: [0.99152431 0.89413211 0.04216446 0.00316801]
# [-0.00847569 -0.10586789  0.04216446  0.00316801]
#   Gradient for Weights: [0.00832438]
#   Gradient for Bias: -0.017252776916611926
#   Loss: 0.0417
# --------------------------------------------------
# Epoch 998
#   Weights: [-2.63004412]
#   Bias: 4.765490512971215
#   Z: [ 4.7637668   2.13455439 -3.12387044 -5.75308286]
#  actual[1 1 0 0]
#   Predictions: [0.9915388  0.8942166  0.04213329 0.00316295]
# [-0.0084612  -0.1057834   0.04213329  0.00316295]
#   Gradient for Weights: [0.00831707]
#   Gradient for Bias: -0.0172370916152556
#   Loss: 0.0416
# --------------------------------------------------
# Epoch 999
#   Weights: [-2.6308751]
#   Bias: 4.767212656517137
#   Z: [ 4.76549051  2.13544639 -3.12464185 -5.75468598]
#  actual[1 1 0 0]
#   Predictions: [0.99155325 0.89430094 0.04210217 0.0031579 ]
# [-0.00844675 -0.10569906  0.04210217  0.0031579 ]
#   Gradient for Weights: [0.00830976]
#   Gradient for Bias: -0.017221435459223
#   Loss: 0.0416
# --------------------------------------------------
# Final Weights: [-2.6308751]
# Final Bias: 4.767212656517137
