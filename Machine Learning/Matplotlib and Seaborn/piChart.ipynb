# %%
import pandas as pn
from matplotlib import pyplot as plt

d=pn.read_excel("linechart.xlsx")


s=d[["Fridge","Dishwasher","Washing Machine"]].sum()
plt.pie(s.values,labels=s.index,autopct="%1.1f%%",explode=(0.1,0.1,0),shadow=True,startangle=140)
plt.show()

# %%
d.plot(kind="bar",x="Quarter")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Q1 2022'),
#   Text(1, 0, 'Q2 2022'),
#   Text(2, 0, 'Q3 2022'),
#   Text(3, 0, 'Q4 2022'),
#   Text(4, 0, 'Q1 2023'),
#   Text(5, 0, 'Q2 2023')])

# %%
import seaborn as sns

sns.histplot(d["Washing Machine"],kde=True)
# Out:
# <Axes: xlabel='Washing Machine', ylabel='Count'>

# %%
sns.scatterplot(x=d["Quarter"],y=d["Fridge"])
# Out:
# <Axes: xlabel='Quarter', ylabel='Fridge'>
