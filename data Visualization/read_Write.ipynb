# %%
import pandas as pn

file=pn.read_csv("m.csv",header=2,na_values=["Independent"],names=["Movies","Genre","Lead Studio",	"Audience score %",	"Profitability"	,"Rotten Tomatoes %", 	"Worldwide Gross",	"Year"])

file.to_csv("new.csv",index=False,header=False)
file
# Out:
#                                 Movies      Genre       Lead Studio  \
# 2   You Will Meet a Tall Dark Stranger     Comedy               NaN
# 3                         When in Rome     Comedy            Disney
# 4                What Happens in Vegas     Comedy               Fox
# 5                  Water For Elephants      Drama  20th Century Fox
# 6                               WALL-E  Animation            Disney
# ..                                 ...        ...               ...
# 72                 Across the Universe    romance               NaN
# 73                       A Serious Man      Drama         Universal
# 74                  A Dangerous Method      Drama               NaN
# 75                          27 Dresses     Comedy               Fox
# 76                (500) Days of Summer     comedy               Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
f = pn.read_excel("mymovies.xlsx")
f
# Out:
# C:\Users\M.Zaid Naeem\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                           Title  Domestic Gross  \
# 0                                           NaN             NaN
# 1                                 Black Panther     700059566.0
# 2                        Avengers: Infinity War     678815482.0
# 3                                 Incredibles 2     608581744.0
# 4                Jurassic World: Fallen Kingdom     416769345.0
# 5                                    Deadpool 2     318491426.0
# 6                         Dr. Seuss' The Grinch     265499485.0
# 7                 Mission: Impossible - Fallout     220159104.0
# 8                          Ant-Man and the Wasp     216648740.0
# 9                       Solo: A Star Wars Story     213767512.0
# 10                                        Venom     213205181.0
# ...

# %%
ff=f.iloc[:10,:]
fe=f.iloc[10:,:]

ff.reset_index(inplace=True)
ff=ff.drop(columns=["index"])
ff=ff.drop(index=0)

fe.reset_index(inplace=True)
fe=fe.drop(columns=["index"])
fe=fe.drop(index=0)

with pn.ExcelWriter("final.xlsx") as writer:
    ff.to_excel(writer, sheet_name="data1", index=False)
    fe.to_excel(writer, sheet_name="data2", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[41], line 12
#       9 fe=fe.drop(columns=["index"])
#      10 fe=fe.drop(index=0)
# ---> 12 with pn.ExcelWriter("final.xlsx") as writer:
#      13     ff.to_excel(writer, sheet_name="data1", index=False)
#      14     fe.to_excel(writer, sheet_name="data2", index=False)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_openpyxl.py:61, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      57 from openpyxl.workbook import Workbook
#      59 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 61 super().__init__(
#      62     path,
#      63     mode=mode,
#      64     storage_options=storage_options,
#      65     if_sheet_exists=if_sheet_exists,
# ...
