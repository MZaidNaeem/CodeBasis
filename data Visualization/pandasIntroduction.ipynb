# %%
import pandas as pn

m=pn.read_csv("movies.csv")
m
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
m.head(3)
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010

# %%
m.tail(4)
# Out:
#                     Film   Genre  Lead Studio  Audience score %  \
# 73         A Serious Man   Drama    Universal                64
# 74    A Dangerous Method   Drama  Independent                89
# 75            27 Dresses  Comedy          Fox                71
# 76  (500) Days of Summer  comedy          Fox                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 73       4.382857                 89         $30.68   2009
# 74       0.448645                 79          $8.97   2011
# 75       5.343622                 40        $160.31   2008
# 76       8.096000                 87         $60.72   2009

# %%
m.sample(3)
# Out:
#                            Film   Genre   Lead Studio  Audience score %  \
# 71                    Beginners  Comedy   Independent                80
# 62              Good Luck Chuck  Comedy     Lionsgate                61
# 61  He's Just Not That Into You  Comedy  Warner Bros.                60
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 71       4.471875                 84         $14.31   2011
# 62       2.367685                  3         $59.19   2007
# 61       7.153600                 42        $178.84   2009

# %%
m[1:5]
# Out:
#                                  Film   Genre            Lead Studio  \
# 1                     Youth in Revolt  Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger  Comedy            Independent
# 3                        When in Rome  Comedy                 Disney
# 4               What Happens in Vegas  Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008

# %%
m.loc[5:,"Genre":"Profitability"]
# Out:
#         Genre       Lead Studio  Audience score %  Profitability
# 5       Drama  20th Century Fox                72       3.081421
# 6   Animation            Disney                89       2.896019
# 7     Romance       Independent                67      11.089742
# 8     Romance       Independent                53       0.005000
# 9      Comedy      Warner Bros.                54       4.184038
# ..        ...               ...               ...            ...
# 72    romance       Independent                84       0.652603
# 73      Drama         Universal                64       4.382857
# 74      Drama       Independent                89       0.448645
# 75     Comedy               Fox                71       5.343622
# 76     comedy               Fox                81       8.096000
#
# [72 rows x 4 columns]

# %%
m.iloc[1:3,2:4]
# Out:
#              Lead Studio  Audience score %
# 1  The Weinstein Company                52
# 2            Independent                35

# %%
m.shape
# Out:
# (77, 8)

# %%
m[m["Genre"]=="Comedy"]
# Out:
#                                   Film   Genre            Lead Studio  \
# 1                      Youth in Revolt  Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger  Comedy            Independent
# 3                         When in Rome  Comedy                 Disney
# 4                What Happens in Vegas  Comedy                    Fox
# 9                      Valentine's Day  Comedy           Warner Bros.
# 13                      The Ugly Truth  Comedy            Independent
# 16                        The Proposal  Comedy                 Disney
# 17              The Invention of Lying  Comedy           Warner Bros.
# 18                  The Heartbreak Kid  Comedy              Paramount
# 21                    The Back-up Plan  Comedy                    CBS
# 24              She's Out of My League  Comedy              Paramount
# 25                Sex and the City Two  Comedy           Warner Bros.
# ...

# %%
m["Genre"].unique()
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Romence',
#        'Comdy', 'Action', 'romance', 'comedy'], dtype=object)

# %%
m["Genre"].value_counts()
# Out:
# Genre
# Comedy       41
# Romance      13
# Drama        13
# Animation     4
# Fantasy       1
# Romence       1
# Comdy         1
# Action        1
# romance       1
# comedy        1
# Name: count, dtype: int64

# %%
m.describe()
# Out:
#          level_0      index  Audience score %  Profitability  \
# count  77.000000  77.000000         77.000000      77.000000
# mean   38.000000  38.000000         63.727273       4.599483
# std    22.371857  22.371857         13.657113       8.031990
# min     0.000000   0.000000         35.000000       0.000000
# 25%    19.000000  19.000000         52.000000       1.751351
# 50%    38.000000  38.000000         64.000000       2.642353
# 75%    57.000000  57.000000         76.000000       5.103117
# max    76.000000  76.000000         89.000000      66.934000
#
#        Rotten Tomatoes %         Year
# count          77.000000    77.000000
# mean           46.701299  2009.077922
# std            26.095001     1.354974
# min             3.000000  2007.000000
# 25%            26.000000  2008.000000
# 50%            45.000000  2009.000000
# 75%            64.000000  2010.000000
# max            96.000000  2011.000000

# %%
m.set_index("Film")
# Out:
#                                     level_0  index    Genre  \
# Film
# Zack and Miri Make a Porno                0      0  Romance
# Youth in Revolt                           1      1   Comedy
# You Will Meet a Tall Dark Stranger        2      2   Comedy
# When in Rome                              3      3   Comedy
# What Happens in Vegas                     4      4   Comedy
# ...                                     ...    ...      ...
# Across the Universe                      72     72  romance
# A Serious Man                            73     73    Drama
# A Dangerous Method                       74     74    Drama
# 27 Dresses                               75     75   Comedy
# (500) Days of Summer                     76     76   comedy
#
#                                               Lead Studio  Audience score %  \
# Film
# Zack and Miri Make a Porno          The Weinstein Company                70
# Youth in Revolt                     The Weinstein Company                52
# ...

# %%
m.set_index("index")
# Out:
#                                      Film  level_0    Genre  \
# index
# 0              Zack and Miri Make a Porno        0  Romance
# 1                         Youth in Revolt        1   Comedy
# 2      You Will Meet a Tall Dark Stranger        2   Comedy
# 3                            When in Rome        3   Comedy
# 4                   What Happens in Vegas        4   Comedy
# ...                                   ...      ...      ...
# 72                    Across the Universe       72  romance
# 73                          A Serious Man       73    Drama
# 74                     A Dangerous Method       74    Drama
# 75                             27 Dresses       75   Comedy
# 76                   (500) Days of Summer       76   comedy
#
#                  Lead Studio  Audience score %  Profitability  \
# index
# 0      The Weinstein Company                70       1.747542
# 1      The Weinstein Company                52       1.090000
# ...

# %%
m["newColumn"]=m.apply(lambda x: x["level_0"]-5,axis=1)
m
# Out:
#                                   Film  level_0  index    Genre  \
# 0           Zack and Miri Make a Porno        0      0  Romance
# 1                      Youth in Revolt        1      1   Comedy
# 2   You Will Meet a Tall Dark Stranger        2      2   Comedy
# 3                         When in Rome        3      3   Comedy
# 4                What Happens in Vegas        4      4   Comedy
# ..                                 ...      ...    ...      ...
# 72                 Across the Universe       72     72  romance
# 73                       A Serious Man       73     73    Drama
# 74                  A Dangerous Method       74     74    Drama
# 75                          27 Dresses       75     75   Comedy
# 76                (500) Days of Summer       76     76   comedy
#
#               Lead Studio  Audience score %  Profitability  Rotten Tomatoes %  \
# 0   The Weinstein Company                70       1.747542                 64
# ...
